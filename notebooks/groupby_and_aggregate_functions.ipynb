# %% [markdown]
# ### GroupBy and Aggregate Functions
#
# GroupBy allows you to group rows together based off some column value, for example, you could group together sales data by the day the sale occured, or group repeast customer data based off the name of the customer. Once you've performed the GroupBy operation you can use an aggregate function off that data. An aggregate function aggregates multiple rows of data into a single output, such as taking the sum of inputs, or counting the number of inputs.

# %%
from pyspark.sql import SparkSession

# %%
spark = SparkSession.builder.appName('groupbyagg').getOrCreate()

# %% [markdown]
# Read in the costumer sales data

# %%
df = spark.read.csv('/FileStore/tables/sales_info.csv', inferSchema=True, header=True)

# %%
df.printSchema()
# Out:
# root
#  |-- Company: string (nullable = true)
#  |-- Person: string (nullable = true)
#  |-- Sales: double (nullable = true)

# %%
df.show()
# Out:
# +-------+-------+-----+
# |Company| Person|Sales|
# +-------+-------+-----+
# |   GOOG|    Sam|200.0|
# |   GOOG|Charlie|120.0|
# |   GOOG|  Frank|340.0|
# |   MSFT|   Tina|600.0|
# |   MSFT|    Amy|124.0|
# |   MSFT|Vanessa|243.0|
# |     FB|   Carl|870.0|
# |     FB|  Sarah|350.0|
# |   APPL|   John|250.0|
# |   APPL|  Linda|130.0|
# |   APPL|   Mike|750.0|
# |   APPL|  Chris|350.0|
# +-------+-------+-----+

# %% [markdown]
# Let's group together by company!

# %%
df.groupBy('Company')
# Out:
# Out[8]: <pyspark.sql.group.GroupedData at 0x7f645f2bbf40>

# %% [markdown]
# This returns a GroupedData object, off of which you can all various methods.

# %%
# Mean
df.groupBy('Company').mean().show()
# Out:
# +-------+-----------------+
# |Company|       avg(Sales)|
# +-------+-----------------+
# |   APPL|            370.0|
# |   GOOG|            220.0|
# |     FB|            610.0|
# |   MSFT|322.3333333333333|
# +-------+-----------------+

# %%
# Count
df.groupBy('Company').count().show()
# Out:
# +-------+-----+
# |Company|count|
# +-------+-----+
# |   APPL|    4|
# |   GOOG|    3|
# |     FB|    2|
# |   MSFT|    3|
# +-------+-----+

# %%
# Max
df.groupBy('Company').max().show()
# Out:
# +-------+----------+
# |Company|max(Sales)|
# +-------+----------+
# |   APPL|     750.0|
# |   GOOG|     340.0|
# |     FB|     870.0|
# |   MSFT|     600.0|
# +-------+----------+

# %%
# Min
df.groupBy('Company').min().show()
# Out:
# +-------+----------+
# |Company|min(Sales)|
# +-------+----------+
# |   APPL|     130.0|
# |   GOOG|     120.0|
# |     FB|     350.0|
# |   MSFT|     124.0|
# +-------+----------+

# %%
# Sum
df.groupBy('Company').sum().show()
# Out:
# +-------+----------+
# |Company|sum(Sales)|
# +-------+----------+
# |   APPL|    1480.0|
# |   GOOG|     660.0|
# |     FB|    1220.0|
# |   MSFT|     967.0|
# +-------+----------+

# %% [markdown]
# Check out this link for more info on other methods:
# http://spark.apache.org/docs/latest/api/python/pyspark.sql.html#pyspark-sql-module
#
# Not all methods need a groupby call, instead you can just call the generalized .agg() method, that will call the aggregate across all rows in the dataframe column specified. It can take in arguments as a single column, or create multiple aggregate calls all at once using dictionary notation.
#
# For example:

# %%
# Max sales across everything
df.agg({'Sales':'max'}).show()
# Out:
# +----------+
# |max(Sales)|
# +----------+
# |     870.0|
# +----------+

# %%
grouped = df.groupBy('Company')

# %%
grouped.agg({'Sales':'max'}).show()
# Out:
# +-------+----------+
# |Company|max(Sales)|
# +-------+----------+
# |   APPL|     750.0|
# |   GOOG|     340.0|
# |     FB|     870.0|
# |   MSFT|     600.0|
# +-------+----------+

# %% [markdown]
# ### Functions
#
# There are a variety of functions you can import from pyspark.sql.functions. Check out the documentation for the full list available: <br>
# http://spark.apache.org/docs/latest/api/python/pyspark.sql.html#module-pyspark.sql.functions

# %%
from pyspark.sql.functions import countDistinct, avg, stddev

# %%
df.select(countDistinct('Sales')).show()
# Out:
# +---------------------+
# |count(DISTINCT Sales)|
# +---------------------+
# |                   11|
# +---------------------+

# %% [markdown]
# Often you will want to change the name, use the .alias() method for this:

# %%
df.select(countDistinct('Sales').alias('Distinct Sales')).show()
# Out:
# +--------------+
# |Distinct Sales|
# +--------------+
# |            11|
# +--------------+

# %%
df.select(avg('Sales')).show()
# Out:
# +-----------------+
# |       avg(Sales)|
# +-----------------+
# |360.5833333333333|
# +-----------------+

# %%
df.select(stddev("Sales")).show()
# Out:
# +------------------+
# |stddev_samp(Sales)|
# +------------------+
# |250.08742410799007|
# +------------------+

# %% [markdown]
# That is a lot of precision for digits! Let's use the format_number to fix that!

# %%
from pyspark.sql.functions import format_number

# %%
sales_std = df.select(stddev("Sales").alias('std'))

# %%
sales_std.show()
# Out:
# +------------------+
# |               std|
# +------------------+
# |250.08742410799007|
# +------------------+

# %%
# format_number("col_name",decimal places)
sales_std.select(format_number('std', 2)).show()
# Out:
# +---------------------+
# |format_number(std, 2)|
# +---------------------+
# |               250.09|
# +---------------------+

# %% [markdown]
# ### Order By
#
# We can easily sort with the orderBy method:

# %%
# OrderBy. Ascending is default method.
df.orderBy('Sales').show()
# Out:
# +-------+-------+-----+
# |Company| Person|Sales|
# +-------+-------+-----+
# |   GOOG|Charlie|120.0|
# |   MSFT|    Amy|124.0|
# |   APPL|  Linda|130.0|
# |   GOOG|    Sam|200.0|
# |   MSFT|Vanessa|243.0|
# |   APPL|   John|250.0|
# |   GOOG|  Frank|340.0|
# |     FB|  Sarah|350.0|
# |   APPL|  Chris|350.0|
# |   MSFT|   Tina|600.0|
# |   APPL|   Mike|750.0|
# |     FB|   Carl|870.0|
# +-------+-------+-----+

# %%
# OrderBy Descending.
df.orderBy(df['Sales'].desc()).show()
# Out:
# +-------+-------+-----+
# |Company| Person|Sales|
# +-------+-------+-----+
# |     FB|   Carl|870.0|
# |   APPL|   Mike|750.0|
# |   MSFT|   Tina|600.0|
# |     FB|  Sarah|350.0|
# |   APPL|  Chris|350.0|
# |   GOOG|  Frank|340.0|
# |   APPL|   John|250.0|
# |   MSFT|Vanessa|243.0|
# |   GOOG|    Sam|200.0|
# |   APPL|  Linda|130.0|
# |   MSFT|    Amy|124.0|
# |   GOOG|Charlie|120.0|
# +-------+-------+-----+

# %%
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
